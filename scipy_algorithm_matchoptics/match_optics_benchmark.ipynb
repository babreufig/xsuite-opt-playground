# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 500)

# %%
# Read dataframe from csv
filepath = "../../../results/001a_change_beta_star_lhcmatch_optimization_results.csv"
df = pd.read_csv(filepath)
print(df)
# Out:
#         Knob    Algorithm  Successful  # Calls       Penalty
# 0     on_o2v         BFGS       False       48  5.000000e-05
# 1     on_o2v     L-BFGS-B        True      894  1.274293e-20
# 2     on_o2v  Nelder-Mead        True     1082  2.121370e-19
# 3     on_o2v          TRF        True       73  1.274281e-20
# 4     on_o2v       Dogbox        True       43  1.274281e-20
# 5     on_o2v     Jacobian        True       22  1.274738e-20
# 6     on_o2h         BFGS       False       48  5.000000e-05
# 7     on_o2h     L-BFGS-B       False       36  5.000000e-05
# 8     on_o2h  Nelder-Mead        True     1323  2.136662e-20
# 9     on_o2h          TRF        True       43  3.913697e-31
# 10    on_o2h       Dogbox        True       43  2.225512e-31
# 11    on_o2h     Jacobian        True       12  8.913050e-19
# 12    on_o8v         BFGS       False       48  5.000000e-05
# 13    on_o8v     L-BFGS-B        True     1466  6.601315e-19
# ...

# %%
# Only print those from df that were successful, grouped by knob and sorted by ascending number of calls
df_successful = df[df["Successful"] == True]
df_sorted = df_successful.sort_values(by=["# Calls"], ascending=True)
df_sorted
# Out:
#         Knob    Algorithm  Successful  # Calls       Penalty
# 71    on_x8v     Jacobian        True        4  8.094520e-17
# 11    on_o2h     Jacobian        True       12  8.913050e-19
# 35    on_a2v     Jacobian        True       12  6.864766e-18
# 29    on_a2h     Jacobian        True       12  6.139512e-20
# 47    on_a8v     Jacobian        True       12  1.226644e-17
# 83  on_sep2v     Jacobian        True       22  3.829297e-20
# 17    on_o8v     Jacobian        True       22  6.602593e-19
# 5     on_o2v     Jacobian        True       22  1.274738e-20
# 59    on_x2v     Jacobian        True       22  1.263595e-16
# 95  on_sep8v     Jacobian        True       22  2.151898e-19
# 65    on_x8h     Jacobian        True       24  7.212279e-19
# 77  on_sep2h     Jacobian        True       32  6.377788e-31
# 41    on_a8h     Jacobian        True       32  7.432207e-20
# 23    on_o8h     Jacobian        True       32  1.694955e-17
# ...
